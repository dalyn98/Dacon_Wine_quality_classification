# %% [markdown]
# 와인은 알코올 함유량이 높을수록  품질이 높다는 주장이 많다.
# 와인은 모든 성분이 __균형__ 을 이룰때 품질이 높다는 주장이 많다.
#
# 알콜과 등급의 상관관계를 좀더 깊게 확인해보자
#
# 모든 성분의의 평균한 값과 품질을 확인해보자

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import patches
from tqdm import tqdm
# %matplotlib inline

train_path = '../train/train.csv'
test_path = '../test/test.csv'
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
train_df.head()
# Out:
#    id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0   1            8.0              0.18         0.37             1.3
# 1   2            7.5              0.38         0.29             4.9
# 2   3            6.1              0.27         0.33             2.2
# 3   4            6.4              0.32         0.50            10.7
# 4   5            8.4              0.37         0.43             2.3
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.040                 15.0                  96.0  0.99120  3.06
# 1      0.021                 38.0                 113.0  0.99026  3.08
# 2      0.021                 26.0                 117.0  0.98860  3.12
# 3      0.047                 57.0                 206.0  0.99680  3.08
# 4      0.063                 12.0                  19.0  0.99550  3.17
#
#    sulphates  alcohol   type  quality
# 0       0.61     12.1  white        6
# 1       0.48     13.0  white        7
# 2       0.30     12.5  white        6
# 3       0.60      9.4  white        5
# 4       0.81     11.2    red        7

# %%
plt.figure(figsize=(20,10))

heat_table = train_df.drop(['id'],axis=1).corr()
heatmap_ax = sns.heatmap(heat_table, annot = True,cmap = 'coolwarm')
heatmap_ax.set_xticklabels(heatmap_ax.get_xticklabels(),fontsize=15,rotation=45)
heatmap_ax.set_yticklabels(heatmap_ax.get_yticklabels(),fontsize=15)
plt.title('correlation between Wine features',fontsize=40)
plt.show()

# %% [markdown]
# quality와 가장 높은 상관관계 : 알코올의 함유량
# 해당 알코올을 등급을 나누어 분석해보는건 어떨까?

# %%
train_df['alcohol'].describe()
# Out:
# count    3231.000000
# mean       10.497108
# std         1.193813
# min         8.400000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000
# Name: alcohol, dtype: float64

# %% [markdown]
# 75% 이상을 high_alcohol,
# 75% 미만을 low_alcohol로 분리한뒤 상관관계를 확인해보자

# %%
train_df['high alcohol'] = 0
train_df.loc[(train_df['alcohol'] >= 11.3),'high alcohol'] =1

# %%
alcohol_df = train_df
alcohol_df.drop('alcohol',axis=1,inplace=True)

# %%
alcohol_df
# Out:
#         id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            8.0              0.18         0.37            1.30
# 1        2            7.5              0.38         0.29            4.90
# 2        3            6.1              0.27         0.33            2.20
# 3        4            6.4              0.32         0.50           10.70
# 4        5            8.4              0.37         0.43            2.30
# ...    ...            ...               ...          ...             ...
# 3226  3227            6.4              0.16         0.31            5.30
# 3227  3228            6.4              0.18         0.28           17.05
# 3228  3229            6.0              0.28         0.25            1.80
# 3229  3230            7.7              0.28         0.29            6.90
# 3230  3231            7.1              0.15         0.34            5.30
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.040                 15.0                  96.0  0.99120  3.06
# 1         0.021                 38.0                 113.0  0.99026  3.08
# 2         0.021                 26.0                 117.0  0.98860  3.12
# 3         0.047                 57.0                 206.0  0.99680  3.08
# 4         0.063                 12.0                  19.0  0.99550  3.17
# ...         ...                  ...                   ...      ...   ...
# 3226      0.043                 42.0                 157.0  0.99455  3.35
# 3227      0.047                 53.0                 139.0  0.99724  3.25
# 3228      0.042                  8.0                 108.0  0.99290  3.08
# 3229      0.041                 29.0                 163.0  0.99520  3.44
# 3230      0.034                 33.0                 104.0  0.99530  3.37
#
#       sulphates   type  quality  high alcohol
# 0          0.61  white        6             1
# 1          0.48  white        7             1
# 2          0.30  white        6             1
# 3          0.60  white        5             0
# 4          0.81    red        7             0
# ...         ...    ...      ...           ...
# 3226       0.47  white        5             0
# 3227       0.35  white        6             0
# 3228       0.55  white        5             0
# 3229       0.60  white        6             0
# 3230       0.52  white        7             0
#
# [3231 rows x 14 columns]

# %%
corr.sort_values(ascending=False)
# Out:
# quality                 1.000000
# high alcohol            0.387343
# free sulfur dioxide     0.068432
# citric acid             0.066630
# pH                      0.036293
# sulphates               0.026895
# id                     -0.011903
# total sulfur dioxide   -0.043504
# residual sugar         -0.045225
# fixed acidity          -0.081833
# chlorides              -0.185623
# volatile acidity       -0.255084
# density                -0.309164
# Name: quality, dtype: float64

# %%
value_df = train_df.loc[:,['fixed acidity', 'volatile acidity', 'citric acid',
       'residual sugar', 'chlorides', 'free sulfur dioxide',
       'total sulfur dioxide', 'density', 'pH', 'sulphates','alcohol','quality']]

# %%
value_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3231 entries, 0 to 3230
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         3231 non-null   float64
#  1   volatile acidity      3231 non-null   float64
#  2   citric acid           3231 non-null   float64
#  3   residual sugar        3231 non-null   float64
#  4   chlorides             3231 non-null   float64
#  5   free sulfur dioxide   3231 non-null   float64
#  6   total sulfur dioxide  3231 non-null   float64
#  7   density               3231 non-null   float64
#  8   pH                    3231 non-null   float64
#  9   sulphates             3231 non-null   float64
#  10  alcohol               3231 non-null   float64
#  11  quality               3231 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 303.0 KB

# %%
value_df.iloc[:,:-1]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               8.0              0.18         0.37            1.30      0.040
# 1               7.5              0.38         0.29            4.90      0.021
# 2               6.1              0.27         0.33            2.20      0.021
# 3               6.4              0.32         0.50           10.70      0.047
# 4               8.4              0.37         0.43            2.30      0.063
# ...             ...               ...          ...             ...        ...
# 3226            6.4              0.16         0.31            5.30      0.043
# 3227            6.4              0.18         0.28           17.05      0.047
# 3228            6.0              0.28         0.25            1.80      0.042
# 3229            7.7              0.28         0.29            6.90      0.041
# 3230            7.1              0.15         0.34            5.30      0.034
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    15.0                  96.0  0.99120  3.06       0.61
# 1                    38.0                 113.0  0.99026  3.08       0.48
# 2                    26.0                 117.0  0.98860  3.12       0.30
# 3                    57.0                 206.0  0.99680  3.08       0.60
# 4                    12.0                  19.0  0.99550  3.17       0.81
# ...                   ...                   ...      ...   ...        ...
# 3226                 42.0                 157.0  0.99455  3.35       0.47
# 3227                 53.0                 139.0  0.99724  3.25       0.35
# 3228                  8.0                 108.0  0.99290  3.08       0.55
# 3229                 29.0                 163.0  0.99520  3.44       0.60
# 3230                 33.0                 104.0  0.99530  3.37       0.52
#
#       alcohol
# 0        12.1
# 1        13.0
# 2        12.5
# 3         9.4
# 4        11.2
# ...       ...
# 3226     10.5
# 3227     10.5
# 3228      9.0
# 3229     10.5
# 3230      9.3
#
# [3231 rows x 11 columns]

# %%
from scipy import stats
zscore_df = value_df.iloc[:,:-1].apply(stats.zscore)
zscore_df['quality'] = value_df['quality']

# %%
zscore_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.613164         -0.973871     0.346320       -0.862826  -0.444893
# 1          0.227151          0.274102    -0.202257       -0.115217  -0.976867
# 2         -0.853685         -0.412283     0.072032       -0.675924  -0.976867
# 3         -0.622077         -0.100290     1.237759        1.089263  -0.248903
# 4          0.921975          0.211703     0.757754       -0.655157   0.199075
# ...             ...               ...          ...             ...        ...
# 3226      -0.622077         -1.098668    -0.065113       -0.032150  -0.360897
# 3227      -0.622077         -0.973871    -0.270829        2.407962  -0.248903
# 3228      -0.930887         -0.349884    -0.476546       -0.758992  -0.388896
# 3229       0.381557         -0.349884    -0.202257        0.300121  -0.416894
# 3230      -0.081659         -1.161067     0.140604       -0.032150  -0.612885
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.896417             -0.363344 -1.135570 -0.952533
# 1                0.426604             -0.058413 -1.443438 -0.828960
# 2               -0.263668              0.013335 -1.987120 -0.581815
# 3                1.519535              1.609735  0.698538 -0.828960
# 4               -1.068985             -1.744499  0.272763 -0.272884
# ...                   ...                   ...       ...       ...
# 3226             0.656695              0.730818 -0.038380  0.839268
# 3227             1.289444              0.407951  0.842646  0.221405
# 3228            -1.299076             -0.148099 -0.578787 -0.828960
# 3229            -0.091100              0.838440  0.174507  1.395344
# 3230             0.138991             -0.219847  0.207259  0.962840
#
#       sulphates   alcohol  quality
# 0      0.524814  1.342873        6
# 1     -0.343803  2.096877        7
# 2     -1.546504  1.677986        6
# 3      0.457997 -0.919137        5
# 4      1.861148  0.588870        7
# ...         ...       ...      ...
# 3226  -0.410620  0.002423        5
# 3227  -1.212420  0.002423        6
# 3228   0.123914 -1.254250        5
# 3229   0.457997  0.002423        6
# 3230  -0.076536 -1.002915        7
#
# [3231 rows x 12 columns]

# %%
zscore_df.loc['total_mean'] = zscore_df.sum(axis=0)

# %%
zscore_df['alcohol'].max()
# Out:
# 3.688661556791884

# %%
zscore_df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          0.613164         -0.973871     0.346320       -0.862826  -0.444893
# 1          0.227151          0.274102    -0.202257       -0.115217  -0.976867
# 2         -0.853685         -0.412283     0.072032       -0.675924  -0.976867
# 3         -0.622077         -0.100290     1.237759        1.089263  -0.248903
# 4          0.921975          0.211703     0.757754       -0.655157   0.199075
# ...             ...               ...          ...             ...        ...
# 3226      -0.622077         -1.098668    -0.065113       -0.032150  -0.360897
# 3227      -0.622077         -0.973871    -0.270829        2.407962  -0.248903
# 3228      -0.930887         -0.349884    -0.476546       -0.758992  -0.388896
# 3229       0.381557         -0.349884    -0.202257        0.300121  -0.416894
# 3230      -0.081659         -1.161067     0.140604       -0.032150  -0.612885
#
#       free sulfur dioxide  total sulfur dioxide   density        pH  \
# 0               -0.896417             -0.363344 -1.135570 -0.952533
# 1                0.426604             -0.058413 -1.443438 -0.828960
# 2               -0.263668              0.013335 -1.987120 -0.581815
# 3                1.519535              1.609735  0.698538 -0.828960
# 4               -1.068985             -1.744499  0.272763 -0.272884
# ...                   ...                   ...       ...       ...
# 3226             0.656695              0.730818 -0.038380  0.839268
# 3227             1.289444              0.407951  0.842646  0.221405
# 3228            -1.299076             -0.148099 -0.578787 -0.828960
# 3229            -0.091100              0.838440  0.174507  1.395344
# 3230             0.138991             -0.219847  0.207259  0.962840
#
#       sulphates   alcohol  quality
# 0      0.524814  1.342873        6
# 1     -0.343803  2.096877        7
# 2     -1.546504  1.677986        6
# 3      0.457997 -0.919137        5
# 4      1.861148  0.588870        7
# ...         ...       ...      ...
# 3226  -0.410620  0.002423        5
# 3227  -1.212420  0.002423        6
# 3228   0.123914 -1.254250        5
# 3229   0.457997  0.002423        6
# 3230  -0.076536 -1.002915        7
#
# [3231 rows x 12 columns]

# %%
zscore_df.sum(axis=0)
# Out:
# fixed acidity           1.843858e-12
# volatile acidity        7.407408e-13
# citric acid            -7.105427e-14
# residual sugar          2.273737e-13
# chlorides              -3.481659e-13
# free sulfur dioxide    -2.593481e-13
# total sulfur dioxide   -1.243450e-13
# density                 5.159251e-11
# pH                     -9.656276e-12
# sulphates              -1.719513e-12
# alcohol                -2.691181e-13
# quality                 1.883400e+04
# dtype: float64

# %%
zscore_df.iloc[:,1:-1].sum(axis=0)
# Out:
# volatile acidity        7.407408e-13
# citric acid            -7.105427e-14
# residual sugar          2.273737e-13
# chlorides              -3.481659e-13
# free sulfur dioxide    -2.593481e-13
# total sulfur dioxide   -1.243450e-13
# density                 5.159251e-11
# pH                     -9.656276e-12
# sulphates              -1.719513e-12
# alcohol                -2.691181e-13
# dtype: float64
